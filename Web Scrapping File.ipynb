# %%
import pandas as pd

# %%
data=pd.read_html('https://results.eci.gov.in/ResultAcGenMar2022/ConstituencywiseS241.htm?ac=1')

# %%
len(data)
# Out:
# 10

# %%
type(data)
# Out:
# list

# %%
result=data[9]

# %%
type(result)
# Out:
# pandas.core.frame.DataFrame

# %%
result
# Out:
#                       0                    1                         2  \
# 0   Uttar Pradesh-Behat  Uttar Pradesh-Behat       Uttar Pradesh-Behat
# 1         Result Status        Result Status             Result Status
# 2                O.S.N.            Candidate                     Party
# 3                     1        Umar Ali Khan           Samajwadi Party
# 4                     2         Naresh Saini    Bharatiya Janata Party
# 5                     3        Poonam Kamboj  Indian National Congress
# 6                     4           Rais Malik       Bahujan Samaj Party
# 7                     5         Sushil Kumar           Aam Aadmi Party
# 8                     6             Ali Khan               Independent
# 9                     7            Mo. IKram               Independent
# 10                    8      Dharampal Singh               Independent
# 11                    9                 NOTA         None of the Above
# ...

# %%
result=result.drop(result.columns[[0,1,2]], axis=0)

# %%
result=result.drop(result.columns[[7, 8]], axis=1)

# %%
result
# Out:
#       0                1                         2       3    4       5      6
# 3     1    Umar Ali Khan           Samajwadi Party  134396  117  134513  47.81
# 4     2     Naresh Saini    Bharatiya Janata Party   96389  244   96633  34.34
# 5     3    Poonam Kamboj  Indian National Congress    1626    6    1632   0.58
# 6     4       Rais Malik       Bahujan Samaj Party   45010   65   45075  16.02
# 7     5     Sushil Kumar           Aam Aadmi Party    1161    1    1162   0.41
# 8     6         Ali Khan               Independent     409    0     409   0.15
# 9     7        Mo. IKram               Independent     271    1     272    0.1
# 10    8  Dharampal Singh               Independent     560    0     560    0.2
# 11    9             NOTA         None of the Above    1116    1    1117    0.4
# 12  NaN            Total                       NaN  280938  435  281373    NaN

# %%
result.drop([12], axis=0, inplace=True)

# %%
result
# Out:
#     0                1                         2       3    4       5      6
# 3   1    Umar Ali Khan           Samajwadi Party  134396  117  134513  47.81
# 4   2     Naresh Saini    Bharatiya Janata Party   96389  244   96633  34.34
# 5   3    Poonam Kamboj  Indian National Congress    1626    6    1632   0.58
# 6   4       Rais Malik       Bahujan Samaj Party   45010   65   45075  16.02
# 7   5     Sushil Kumar           Aam Aadmi Party    1161    1    1162   0.41
# 8   6         Ali Khan               Independent     409    0     409   0.15
# 9   7        Mo. IKram               Independent     271    1     272    0.1
# 10  8  Dharampal Singh               Independent     560    0     560    0.2
# 11  9             NOTA         None of the Above    1116    1    1117    0.4

# %%
 result.to_csv('Behat.csv', index=False,header=None)
